# %%
x=10
y="Sri Lanka"
z=5.67
print(x)
print(y)
print(z)
# Out:
# 10
# Sri Lanka
# 5.67

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
print(type(z))
# Out:
# <class 'float'>

# %%
25aAB_c99_=100
print(aABc99)
# Out:
#   Cell In[10], line 1
#     25aAB_c99_=100
#      ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # Arithmatic Operators

# %%
print(5+2)
print(5-2)
print(5*2)
print(5/2)
print(5//2)
print(5%2)
print(5**2)
# Out:
# 7
# 3
# 10
# 2.5
# 2
# 1
# 25

# %%
a=5
b=2
a=b
print(a)
# Out:
# 2

# %%
a=5
b=2
a+=b
print(a)
# Out:
# 7

# %%
a=5
b=2
a-=b
print(a)
# Out:
# 3

# %%
a=5
b=2
a*=b
print(a)
# Out:
# 10

# %%
a=5
b=2
a/=b
print(a)
# Out:
# 2.5

# %%
a=5
b=2
a//=b
print(a)
# Out:
# 2

# %%
a=5
b=2
a%=b
print(a)
# Out:
# 1

# %%
a=5
b=2
a==b
# Out:
# False

# %%
a=5
b=2
a!=b
# Out:
# True

# %% [markdown]
# # Logical Operator

# %% [markdown]
# # NOT

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# # AND

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %% [markdown]
# # OR

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
Num1=int(input("Enter the first number: "))
Num2=int(input("Enter the second number: "))
Sum=Num1+Num2
print("The sum of the 2 numbers entered is ",Sum)
# Out:
# Enter the first number:  34
# Enter the second number:  27
# The sum of the 2 numbers entered is  61

# %%
Fname=input("Enter your first name: ")
Lname=input("Enter your last name: ")
print("Hello",Fname+" "+Lname)
# Out:
# Enter your first name:
# Enter your last name:
# Hello

# %%
fName=input("Enter your name: ")
lName=input("Enter your last name: ")
sub1=int(input("Enter the marks of sub 1: "))
sub2=int(input("Enter the marks of sub 2: "))
sub3=int(input("Enter the marks of sub 3: "))
sub4=int(input("Enter the marks of sub 4: "))
total=sub1+sub2+sub3+sub4
avg=total/4
print("")
print("Hello",fName+" "+lName)
print("Marks of sub 1 is ",sub1)
print("Marks of sub 2 is ",sub2)
print("Marks of sub 3 is ",sub3)
print("Marks of sub 4 is ",sub4)
print("The total mark is ",total)
print("The average is ",avg)
# Out:
# Enter your name:  Osandha
# Enter your last name:  Siriwardena
# Enter the marks of sub 1:  87
# Enter the marks of sub 2:  60
# Enter the marks of sub 3:  56
# Enter the marks of sub 4:  98
# Hello Osandha Siriwardena
# Marks of sub 1 is  87
# Marks of sub 2 is  60
# Marks of sub 3 is  56
# Marks of sub 4 is  98
# The total mark is  301
# The average is  75.25

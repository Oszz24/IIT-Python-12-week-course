# %%
UserName=input("Enter your name: ")
UserLearn=input("Enter what you learn: ")
print("My name is ",UserName, ",")
print("I study at SLIIT university,")
print("I am currently learning ",UserLearn)
# Out:
# Enter your name:  Osandha Siriwardena
# Enter what you learn:  Python programming
# My name is  Osandha Siriwardena ,
# I study at SLIIT university
# I am currently learning  Python programming
